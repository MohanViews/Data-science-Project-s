# %% [markdown]
# ## Using Google API Collecting details of a Required Channel and Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyAOtkK9zohzXRcCZ-X88PYx3xkotuvveEI"

# %% [markdown]
# # Function to retrive data like Title, likes, dislikes, Comment of the required channel

# %%
from googleapiclient.discovery import build
def get_channel_videos(api_key, channel_id, max_results=40):
    youtube = build("youtube", "v3", developerKey=api_key)

    request = youtube.search().list(
        part="snippet",
        channelId=channel_id,
        maxResults=max_results,
        type="video"
    )

    response = request.execute()
    video_details = []

    for i in response["items"]:
        video_id = i["id"]["videoId"]
        video_data = youtube.videos().list(
            part="snippet,statistics",
            id=video_id
        ).execute()

        snippet = video_data["items"][0]["snippet"]
        statistics = video_data["items"][0]["statistics"]

        video_info = {
            "title": snippet["title"],
            "published_at": snippet["publishedAt"],
            "views": statistics.get("viewCount", 0),
            "likes": statistics.get("likeCount", 0),
            "dislikes": statistics.get("dislikeCount", 0),
            "comments": statistics.get("commentCount", 0),
        }

        video_details.append(video_info)

    return video_details

# %%
# "UCdKS_mDSLUkS6vDK6u1mjOg"  ---> Channel ID ( Lost frequency Musical Band)

# %%
channel_id=str(input('enter channel Id: '))
videos = get_channel_videos(os.environ.get("GOOGLE_API_KEY"), channel_id)
# Out:
# enter channel Id: UCdKS_mDSLUkS6vDK6u1mjOg

# %%
# data is extracted from the required channel and the collected data is put in a dataFrame

# %%
import pandas as pd
df=pd.DataFrame(videos)
df
# Out:
# C:\Users\MURALI\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                                                 title          published_at  \
# 0   1 BILLION STREAMS!!!!  🫶🏻  #lostfrequencies #e...  2024-03-13T15:20:55Z
# 1   These lyrics are me this summer 🙂‍↕️ #electron...  2024-07-02T14:22:19Z
# 2   Lost Frequencies & Netsky - Leave You In The P...  2023-11-10T09:01:38Z
# 3   Lost Frequencies ft. James Blunt - Melody (Off...  2018-04-28T13:19:59Z
# 4   Lost Frequencies ft. Calum Scott - Where Are Y...  2021-08-18T15:00:11Z
# 5   Lost Frequencies & Tom Odell - Black Friday (P...  2024-07-19T07:00:07Z
# 6   Lost Frequencies & David Kushner - In My Bones...  2024-05-15T06:00:06Z
# 7   Lost Frequencies ft. The NGHBRS - Like I Love ...  2018-09-14T13:59:58Z
# 8   Lost Frequencies, Elley Duhé, X Ambassadors - ...  2023-01-19T17:00:09Z
# 9   Lost Frequencies & James Arthur - Questions (O...  2022-06-16T17:00:11Z
# 10  Lost Frequencies - Sun Is Shining (Official Mu...  2019-08-09T09:58:19Z
# 11  Lost Frequencies & Zonderling - Crazy (Officia...  2017-11-24T14:52:54Z
# 12    Lost Frequencies - The Feeling (Official video)  2023-08-02T15:00:08Z
# 13  Lost Frequencies, Zonderling & Kelvin Jones - ...  2020-04-17T09:15:54Z
# 14  Lost Frequencies - Love Is The Only Thing (Off...  2024-11-08T09:12:21Z
# 15  Lost Frequencies - The Feeling (Lost Frequenci...  2023-08-11T15:30:59Z
# 16  Lost Frequencies & Mathieu Koss - Don't Leave ...  2020-08-11T10:00:04Z
# 17  Lost Frequencies & Alexander Stewart - Gone (A...  2023-11-10T09:01:54Z
# 18  In My Bones with @david.kushner IS OUT NOWW #l...  2024-04-24T15:00:39Z
# 19  Lost Frequencies & Tom Odell - Black Friday (p...  2024-10-23T09:47:01Z
# 20  Lost Frequencies & Netsky - Here With You (Off...  2017-07-18T11:15:05Z
# 21  Lost Frequencies ft. Mokita - Black & Blue (Of...  2019-09-13T10:00:02Z
# 22  Lost Frequencies - All Stand Together (Officia...  2023-11-10T09:01:12Z
# 23  Lost Frequencies feat. Easton Corbin - One Mor...  2020-07-24T10:00:17Z
# 24  Lost Frequencies feat. Easton Corbin - One Mor...  2020-09-25T11:35:24Z
# 25                   Lost Frequencies - Chemical High  2022-08-19T08:32:30Z
# 26  Lost Frequencies – All or Nothing (Official Vi...  2017-02-17T10:41:09Z
# 27     Lost Frequencies - Rise (Official Music Video)  2021-03-19T09:00:13Z
# 28  Lost Frequencies & Mathieu Koss - Don't Leave ...  2020-07-31T14:49:18Z
# 29  This track feels like a good confetti moment 🥲...  2024-07-11T15:00:11Z
# 30     Lost Frequencies - Sun Is Shining (Deluxe Mix)  2019-10-04T08:00:02Z
# 31  Lost Frequencies & Declan J Donovan - Just Wan...  2024-03-25T10:26:20Z
# 32  Lost Frequencies - Sweet Dreams (Pretty Pink R...  2020-02-28T14:09:08Z
# 33  Ed Sheeran - Eyes Closed (Lost Frequencies Remix)  2023-05-19T08:14:47Z
# 34  Lost Frequencies vs. Love Harder feat. Flynn -...  2020-10-09T10:00:13Z
# 35  Lost Frequencies & Tom Gregory - Dive (Deluxe ...  2023-10-13T08:27:47Z
# 36  Lost Frequencies & Isak Danielson - Broken (Lo...  2023-04-21T10:47:14Z
# 37  Lost Frequencies - Before Today (feat. Nathali...  2019-10-04T08:00:06Z
# 38  Lost Frequencies feat. Flynn - Recognise (Offi...  2019-03-13T13:00:10Z
# 39  Lost Frequencies & Tom Gregory - Dive (Officia...  2023-10-02T08:01:04Z
#
#         views    likes  dislikes comments
# 0      402759    11372         0      301
# 1       28368     1753         0       95
# 2      110895     2433         0       61
# 3   157242079   797503         0    10220
# 4   172445381  1061075         0     9372
# 5     4519674    49383         0      549
# 6     5523789    41772         0      463
# 7    68834181   395295         0     4313
# 8    23344580   141396         0     1856
# 9    13121855    99073         0      925
# 10    3852307    61469         0     1218
# 11  118467844   666256         0     8666
# 12   12474504    83887         0      752
# 13   18506786   145650         0     1219
# 14     270634     9861         0      290
# 15    4989546    38898         0      359
# 16   23600674   193858         0     1887
# 17      77377     1566         0       44
# 18      19396     1339         0       63
# 19     111856     3481         0      116
# 20    8737833   115828         0     1861
# 21    1172788    20882         0      412
# 22     627752     9425         0      176
# 23     762244    14127         0      293
# 24     429596     5271         0      132
# 25     557395     8676         0      228
# 26    3687720    38912         0      499
# 27   17020316   138010         0     2145
# 28    1850975    22265         0      362
# 29      27564     1560         0       47
# 30    1787865    15897         0      272
# 31      60076     1575         0       59
# 32    3211190    30316         0      369
# 33     284562     4722         0      109
# 34     402076     8044         0      180
# 35     693484     9025         0      196
# 36    1773551    20020         0      357
# 37     788346     7253         0      160
# 38    3030710    37444         0      502
# 39    3739014    25082         0      285

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         40 non-null     object
#  1   published_at  40 non-null     object
#  2   views         40 non-null     object
#  3   likes         40 non-null     object
#  4   dislikes      40 non-null     int64
#  5   comments      40 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.0+ KB

# %%
df['published_at'] = pd.to_datetime(df['published_at'])

df['views'] = df['views'].str.replace(',', '').astype(int)
df['likes'] = df['likes'].astype(int)
df['comments'] = df['comments'].astype(int)

# %%
# Data processing for analysis purpose

# %%
def analyze_youtube_data(df):
    # Create a copy of the dataframe
    df_analysis = df.copy()
    
    
    df_analysis['engagement_rate'] = ((df_analysis['likes'] + df_analysis['comments']) / df_analysis['views']) * 100
    df_analysis['like_to_dislike_ratio'] = df_analysis['likes'] / df_analysis['dislikes']
    
    
    df_analysis['year'] = df_analysis['published_at'].dt.year
    df_analysis['month'] = df_analysis['published_at'].dt.month
    df_analysis['day_of_week'] = df_analysis['published_at'].dt.day_name()
    
    return df_analysis

def generate_channel_insights(df):
    """Generate key insights about the channel"""
    insights = {
        'total_videos': len(df),
        'total_views': df['views'].sum(),
        'avg_views': df['views'].mean(),
        'total_likes': df['likes'].sum(),
        'avg_likes': df['likes'].mean(),
        'total_comments': df['comments'].sum(),
        'avg_comments': df['comments'].mean(),
        'avg_engagement_rate': ((df['likes'] + df['comments']) / df['views']).mean() * 100
    }
    return insights

def plot_views_over_time(df):
    """Plot views trend over time"""
    plt.figure(figsize=(15, 6))
    plt.plot(df['published_at'], df['views'], marker='o')
    plt.title('Views Trend Over Time')
    plt.xlabel('Publication Date')
    plt.ylabel('Views')
    plt.xticks(rotation=45)
    plt.grid(True)
    return plt

def plot_engagement_metrics(df):
    """Plot engagement metrics distribution"""
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    
    sns.histplot(data=df, x='views', ax=axes[0,0])
    axes[0,0].set_title('Views Distribution')
    
    
    sns.histplot(data=df, x='likes', ax=axes[0,1])
    axes[0,1].set_title('Likes Distribution')
    
    
    sns.histplot(data=df, x='comments', ax=axes[1,0])
    axes[1,0].set_title('Comments Distribution')
    
    # Engagement rate distribution
    sns.histplot(data=df, x='engagement_rate', ax=axes[1,1])
    axes[1,1].set_title('Engagement Rate Distribution')
    
    plt.tight_layout()
    return plt

def analyze_best_performing_content(df):
    """Analyze top performing content"""
    top_videos = {
        'most_viewed': df.nlargest(5, 'views')[['title', 'views', 'published_at']],
        'most_liked': df.nlargest(5, 'likes')[['title', 'likes', 'views']],
        'most_commented': df.nlargest(5, 'comments')[['title', 'comments', 'views']],
        'highest_engagement': df.nlargest(5, 'engagement_rate')[['title', 'engagement_rate', 'views']]
    }
    return top_videos

def perform_time_analysis(df):
    """Analyze posting patterns and performance by time"""
    time_analysis = {
        'avg_views_by_day': df.groupby('day_of_week')['views'].mean().sort_values(ascending=False),
        'avg_engagement_by_month': df.groupby('month')['engagement_rate'].mean(),
        'videos_per_month': df.groupby('month').size()
    }
    return time_analysis

# Main analysis execution
def main():
    # Process the data
    df_analyzed = analyze_youtube_data(df)
    
    # Generate insights
    insights = generate_channel_insights(df_analyzed)
    print("\nChannel Insights:")
    for key, value in insights.items():
        print(f"{key}: {value:,.2f}")
    
    # Generate and save plots
    plot_views_over_time(df_analyzed)
    plt.savefig('views_trend.png')
    plt.close()
    
    plot_engagement_metrics(df_analyzed)
    plt.savefig('engagement_metrics.png')
    plt.close()
    
    # Analyze top performing content
    top_content = analyze_best_performing_content(df_analyzed)
    print("\nTop Performing Videos:")
    for category, videos in top_content.items():
        print(f"\n{category.replace('_', ' ').title()}:")
        print(videos)
    
    # Time-based analysis
    time_analysis = perform_time_analysis(df_analyzed)
    print("\nTime-Based Analysis:")
    for key, value in time_analysis.items():
        print(f"\n{key}:")
        print(value)

# %%
if __name__ == "__main__":
    main()
# Out:
# Channel Insights:
# total_videos: 40.00
# total_views: 678,589,542.00
# avg_views: 16,964,738.55
# total_likes: 4,341,654.00
# avg_likes: 108,541.35
# total_comments: 51,413.00
# avg_comments: 1,285.33
# avg_engagement_rate: 1.76
# C:\Users\MURALI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\MURALI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\MURALI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\MURALI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Top Performing Videos:
#
# Most Viewed:
#                                                 title      views  \
# 4   Lost Frequencies ft. Calum Scott - Where Are Y...  172445381
# 3   Lost Frequencies ft. James Blunt - Melody (Off...  157242079
# 11  Lost Frequencies & Zonderling - Crazy (Officia...  118467844
# 7   Lost Frequencies ft. The NGHBRS - Like I Love ...   68834181
# 16  Lost Frequencies & Mathieu Koss - Don't Leave ...   23600674
#
#                 published_at
# 4  2021-08-18 15:00:11+00:00
# 3  2018-04-28 13:19:59+00:00
# 11 2017-11-24 14:52:54+00:00
# 7  2018-09-14 13:59:58+00:00
# 16 2020-08-11 10:00:04+00:00
#
# Most Liked:
#                                                 title    likes      views
# 4   Lost Frequencies ft. Calum Scott - Where Are Y...  1061075  172445381
# 3   Lost Frequencies ft. James Blunt - Melody (Off...   797503  157242079
# 11  Lost Frequencies & Zonderling - Crazy (Officia...   666256  118467844
# 7   Lost Frequencies ft. The NGHBRS - Like I Love ...   395295   68834181
# 16  Lost Frequencies & Mathieu Koss - Don't Leave ...   193858   23600674
#
# Most Commented:
#                                                 title  comments      views
# 3   Lost Frequencies ft. James Blunt - Melody (Off...     10220  157242079
# 4   Lost Frequencies ft. Calum Scott - Where Are Y...      9372  172445381
# 11  Lost Frequencies & Zonderling - Crazy (Officia...      8666  118467844
# 7   Lost Frequencies ft. The NGHBRS - Like I Love ...      4313   68834181
# 27     Lost Frequencies - Rise (Official Music Video)      2145   17020316
#
# Highest Engagement:
#                                                 title  engagement_rate   views
# 18  In My Bones with @david.kushner IS OUT NOWW #l...         7.228294   19396
# 1   These lyrics are me this summer 🙂‍↕️ #electron...         6.514382   28368
# 29  This track feels like a good confetti moment 🥲...         5.830068   27564
# 14  Lost Frequencies - Love Is The Only Thing (Off...         3.750822  270634
# 19  Lost Frequencies & Tom Odell - Black Friday (p...         3.215742  111856
#
# Time-Based Analysis:
#
# avg_views_by_day:
# day_of_week
# Saturday     1.572421e+08
# Wednesday    2.771548e+07
# Thursday     1.216467e+07
# Tuesday      1.078896e+07
# Friday       1.061163e+07
# Monday       1.899545e+06
# Name: views, dtype: float64
#
# avg_engagement_by_month:
# month
# 1     0.613641
# 2     1.012137
# 3     1.923414
# 4     2.421127
# 5     1.231149
# 6     0.762072
# 7     2.985055
# 8     1.023353
# 9     1.217968
# 10    1.518988
# 11    2.035931
# Name: engagement_rate, dtype: float64
#
# videos_per_month:
# month
# 1     1
# 2     2
# 3     4
# 4     4
# 5     2
# 6     1
# 7     6
# 8     6
# 9     3
# 10    6
# 11    5
# dtype: int64
